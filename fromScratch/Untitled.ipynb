# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {
    "Feature1": [
        5.1, 5.2, 5.0, 5.3, 5.4, 5.2, 5.1, 5.3, 5.0, 5.5,  # Cluster
        5.1, 5.2, 5.3, 5.4, 5.5, 5.2, 5.1, 5.3, 5.0, 5.4,  # Cluster
        5.2, 5.1, 5.3, 5.5, 5.4, 5.1, 5.2, 5.3, 5.5, 5.0,  # Cluster
        15.0, -5.0, 20.0, -10.0, 25.0  # Anomalies
    ],
    "Feature2": [
        3.2, 3.1, 3.0, 3.3, 3.4, 3.2, 3.1, 3.3, 3.0, 3.5,  # Cluster
        3.2, 3.1, 3.3, 3.4, 3.5, 3.2, 3.1, 3.3, 3.0, 3.4,  # Cluster
        3.1, 3.2, 3.3, 3.4, 3.5, 3.0, 3.2, 3.1, 3.3, 3.4,  # Cluster
        10.0, -10.0, 25.0, -15.0, 30.0  # Anomalies
    ]
}

# %%
plt.scatter(data['Feature1'], data['Feature2'], color='blue', marker='o', label='Data Points')
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.title("Scatter Plot of Dataset")
plt.legend()
plt.grid(True)
plt.show()

# %%
def GuassianDistribution(dataset):
    m,n = dataset.shape
    mu= np.zeros(n)
    #mean calc
    for i in range(n):
        for j in range(m):
        mu[i] += m[j]
# Out:
#   Cell In[16], line 1
#     def GuassianDistribution():
#                                ^
# SyntaxError: incomplete input
