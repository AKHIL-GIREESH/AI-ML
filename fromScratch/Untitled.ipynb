# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = {
    "Feature1": [2.1, 2.5, 1.9, 8.2, 7.8, 8.0, 5.1, 5.3, 4.8],
    "Feature2": [3.2, 3.0, 3.1, 7.1, 6.9, 7.3, 2.2, 2.5, 2.1],
}

# %%
plt.scatter(data['Feature1'], data['Feature2'], color='blue', marker='o', label='Data Points')
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.title("Scatter Plot of Dataset")
plt.legend()
plt.grid(True)
plt.show()
